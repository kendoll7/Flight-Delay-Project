# %%
import hvplot.pandas
import pandas as pd
import geopandas as gpd
import os
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# Test coordinates
# coordinates = {
 #   "latitude": [37.615223, 37.363949, 28.4311577] ,
 #   "longitude": [-122.389977, -121.928940,-81.308083 ],
 #   "Airport": ["San Francisio Airport", "San Jose Airport", "Orlando Airport"],
  #  "Country": ["US", "US", "US"],
  #  "Landed": [3,4,10], 
#}

# %%
file = "./coord_table.csv"
file_df = pd.read_csv(file)
# Out:
#      Unnamed: 0                              Airport  Latitude  Longitude  \
# 0             0         Denver International Airport  39.85891 -104.67326
# 1             1    Los Angeles International Airport  33.94251 -118.40897
# 2             2      Vancouver International Airport  49.19489 -123.17923
# 3             3             Burbank Bob Hope Airport  34.20056 -118.35925
# 4             4     John Wayne Airport-Orange County  33.67803 -117.86368
# ..          ...                                  ...       ...        ...
# 120         120            McClellan-Palomar Airport  33.12809 -117.28115
# 121         121                   Scottsdale Airport  33.62282 -111.91098
# 122         122  Charles B. Wheeler Downtown Airport  39.12118  -94.59153
# 123         123            Lawrence G. Hanscom Field  42.46982  -71.28839
# 124         124    Southwest Oregon Regional Airport  43.41706 -124.24373
#
#     Airport Code  Count
# 0            den      9
# 1            lax     29
# ...

# %%
coordinates_df = pd.DataFrame(coordinates)

# %%
countries = gpd.read_file(
               gpd.datasets.get_path("naturalearth_lowres"))
countries
# Out:
# /var/folders/9x/fv5vqyzs07x4x5whb627xz540000gn/T/ipykernel_39208/1065752456.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# ...

# %%
countries.plot(color="lightgrey")
# Out:
# <Axes: >

# %%
fig, ax = plt.subplots(1, 1)

countries[countries["iso_a3"] == "USA"].plot(color="lightgrey")
# Out:
# <Axes: >

# %%
file_df.plot(x="Longitude", y="Latitude", kind="scatter",c = "Count", 
        colormap="Reds")
# Out:
# <Axes: xlabel='Longitude', ylabel='Latitude'>

# %%
fig, ax = plt.subplots(figsize=(10,10))


countries = gpd.read_file(  
     gpd.datasets.get_path("naturalearth_lowres"))
countries.plot(color="lightgrey",
                                                 ax=ax)
file_df.plot(x="Longitude", y="Latitude", kind="scatter",c = "Count", 
        colormap="Reds", title="Destination Heat Map", ax=ax,)

plt.show()
# Out:
# /var/folders/9x/fv5vqyzs07x4x5whb627xz540000gn/T/ipykernel_39208/3705499419.py:5: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   gpd.datasets.get_path("naturalearth_lowres"))
