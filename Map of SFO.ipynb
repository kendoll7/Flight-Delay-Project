# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Create a dictionary containing coordinates
coordinates = {
    "latitude": [37.7749,  33.942791],
    "longitude": [-122.4194, -118.410042],
    "City": ["SFO", "LAX"],
    "Population": [1000000, 10000000]
}

# %%
# Create a Pandas DataFrame containing coordinates
coordinates_df = pd.DataFrame(coordinates)

# Display sample data
coordinates_df
# Out:
#     latitude   longitude City  Population
# 0  37.774900 -122.419400  SFO     1000000
# 1  33.942791 -118.410042  LAX    10000000

# %%
# Configure the map plot_1
map_plot_1 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM"
)

# Display the map plot_1
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]

# %%
import pandas as pd 
    
# making dataframe 
df = pd.read_csv("coord_table.csv") 
   
# output the dataframe
print(df)
# Out:
#      Unnamed: 0                              Airport  Latitude  Longitude  \
# 0             0         Denver International Airport  39.85891 -104.67326
# 1             1    Los Angeles International Airport  33.94251 -118.40897
# 2             2      Vancouver International Airport  49.19489 -123.17923
# 3             3             Burbank Bob Hope Airport  34.20056 -118.35925
# 4             4     John Wayne Airport-Orange County  33.67803 -117.86368
# ..          ...                                  ...       ...        ...
# 120         120            McClellan-Palomar Airport  33.12809 -117.28115
# 121         121                   Scottsdale Airport  33.62282 -111.91098
# 122         122  Charles B. Wheeler Downtown Airport  39.12118  -94.59153
# 123         123            Lawrence G. Hanscom Field  42.46982  -71.28839
# 124         124    Southwest Oregon Regional Airport  43.41706 -124.24373
#
#     Airport Code  Count
# 0            den      9
# 1            lax     29
# ...

# %%
large_df = df[df["Count"] >= 5]

destination_lat =  list(large_df["Latitude"])
print(destination_lat)

destination_long = list(large_df["Longitude"])
print(destination_long)

destination_code = list(large_df["Airport Code"])
print(destination_code)

destination_count = list(large_df["Count"])
print(destination_count)

destination_count_scaled = []
for x in destination_count:
        destination_count_scaled.append((x*100)**2)


print(destination_count_scaled)
# Out:
# [39.85891, 33.94251, 49.19489, 34.20056, 33.67803, 51.47115, 44.88217, 36.08521, 47.44899, 33.82807, 33.43551, 30.19453, 21.32452, 41.97959, 38.94877, 43.56156, 20.89861, 32.73235, 40.78688, 32.89595, 29.98687, 40.63983, 40.69709, 33.64099, 19.4363, 26.07147, 42.36514, 37.4492, 25.07773, 23.15185]
# [-104.67326, -118.40897, -123.17923, -118.35925, -117.86368, -0.45649, -93.20835, -115.15068, -122.30929, -116.50696, -111.99807, -97.66987, -157.92507, -87.90446, -77.4491, -116.23984, -156.43028, -117.19744, -111.98203, -97.0372, -95.34212, -73.77874, -74.17557, -84.42265, -99.0721, -80.144, -71.01777, 126.45095, 121.23282, -109.72104]
# ['den', 'lax', 'yvr', 'bur', 'sna', 'lhr', 'msp', 'las', 'sea', 'psp', 'phx', 'aus', 'hnl', 'ord', 'iad', 'boi', 'ogg', 'san', 'slc', 'dfw', 'iah', 'jfk', 'ewr', 'atl', 'mex', 'fll', 'bos', 'icn', 'tpe', 'sjd']
# [9, 29, 5, 7, 13, 5, 6, 17, 12, 8, 13, 6, 7, 12, 8, 6, 5, 16, 11, 11, 9, 18, 10, 6, 6, 5, 10, 5, 5, 5]
# ...

# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Create a dictionary containing coordinates
coordinates = {
    "latitude": destination_lat,
    "longitude": destination_long,
    "City": destination_code,
    "Flight Count": destination_count_scaled
}

# %%
# Create a Pandas DataFrame containing coordinates
coordinates_df = pd.DataFrame(coordinates)

# Display sample data
coordinates_df
# Out:
#     latitude  longitude City  Flight Count
# 0   39.85891 -104.67326  den        810000
# 1   33.94251 -118.40897  lax       8410000
# 2   49.19489 -123.17923  yvr        250000
# 3   34.20056 -118.35925  bur        490000
# 4   33.67803 -117.86368  sna       1690000
# 5   51.47115   -0.45649  lhr        250000
# 6   44.88217  -93.20835  msp        360000
# 7   36.08521 -115.15068  las       2890000
# 8   47.44899 -122.30929  sea       1440000
# 9   33.82807 -116.50696  psp        640000
# 10  33.43551 -111.99807  phx       1690000
# 11  30.19453  -97.66987  aus        360000
# 12  21.32452 -157.92507  hnl        490000
# 13  41.97959  -87.90446  ord       1440000
# 14  38.94877  -77.44910  iad        640000
# 15  43.56156 -116.23984  boi        360000
# 16  20.89861 -156.43028  ogg        250000
# 17  32.73235 -117.19744  san       2560000
# 18  40.78688 -111.98203  slc       1210000
# 19  32.89595  -97.03720  dfw       1210000
# 20  29.98687  -95.34212  iah        810000
# ...

# %%
df.hvplot.points(x='Longitude', y='Latitude', padding=0.2, hover_cols='all', width=300) * \
df.hvplot.labels(x='Longitude', y='Latitude', text='City', text_baseline='bottom', hover=False) * \
df.hvplot.labels(x='Longitude', y='Latitude', text='Flight Count', text_baseline='top', hover=False)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# Cell In[138], line 3
#       1 df.hvplot.points(x='Longitude', y='Latitude', padding=0.2, hover_cols='all', width=300) * \
#       2 df.hvplot.labels(x='Longitude', y='Latitude', text='City', text_baseline='bottom', hover=False) * \
# ----> 3 df.hvplot.labels(x='Longitude', y='Latitude', text='Flight Count', text_baseline='top', hover=False)
#
# File ~\anaconda3\envs\hvplot-env\lib\site-packages\hvplot\plotting\core.py:1815, in hvPlotTabular.labels(self, x, y, text, **kwds)
#    1758 def labels(self, x=None, y=None, text=None, **kwds):
#    1759     """
#    1760     Labels plot.
#    1761
#    (...)
#    1813     - Plotly: https://plotly.com/python/text-and-annotations/
#    1814     """
# -> 1815     return self(x, y, text=text, kind="labels", **kwds)
#
# ...

# %%
# Configure the map plot_3
map_plot_3 = coordinates_df.hvplot.points(
    "longitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 800,
    size = "Flight Count",
    scale = 0.01,
    color = "City",
    #c = "Flight Count",
    #label = "City",
    hover=False
)  

coordinates_df.hvplot.points(x='longitude', y='latitude', padding=0.2, hover_cols='all', width=300)
coordinates_df.hvplot.labels(x="longitude", y="latitude", text="City", text_baseline="top", hover= False)
coordinates_df.hvplot.labels(x="longitude", y="latitude", text="Flight Count", text_baseline="bottom", hover= False)

#df.hvplot.points(x='Longitude', y='Latitude', padding=0.2, hover_cols='all', width=300) * \
#df.hvplot.labels(x='Longitude', y='Latitude', text='City', text_baseline='bottom', hover=False) * \
#df.hvplot.labels(x='Longitude', y='Latitude', text='Country', text_baseline='top', hover=False)

# Display the map plot
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (City,Flight Count)

# %%
import hvplot.pandas  # noqa
import pandas as pd

df = pd.DataFrame(
    {'City': ['Buenos Aires', 'Brasilia', 'Santiago', 'Bogota', 'Caracas'],
     'Country': ['Argentina', 'Brazil', 'Chile', 'Colombia', 'Venezuela'],
     'Latitude': [-34.58, -15.78, -33.45, 4.60, 10.48],
     'Longitude': [-58.66, -47.91, -70.66, -74.08, -66.86]})
df

df.hvplot.points(x='Longitude', y='Latitude', padding=0.2, hover_cols='all', width=300) * \
df.hvplot.labels(x='Longitude', y='Latitude', text='City', text_baseline='bottom', hover=False) * \
df.hvplot.labels(x='Longitude', y='Latitude', text='Country', text_baseline='top', hover=False)
# Out:
# :Overlay
#    .Points.I  :Points   [Longitude,Latitude]   (index,City,Country)
#    .Labels.I  :Labels   [Longitude,Latitude]   (City)
#    .Labels.II :Labels   [Longitude,Latitude]   (Country)
